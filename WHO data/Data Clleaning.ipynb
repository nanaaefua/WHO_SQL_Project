# %%
import json
import pandas as pd
import numpy as np

import re

from sqlalchemy import create_engine
import psycopg2

# from config import db_password

import time

# %%
death = pd.read_csv("../sql_project/WHO_MHExp_and_Deaths.csv")

# %%
WHO_deaths_df = pd.DataFrame(death)

# %%
WHO_deaths_df.head()
# Out:
#   Country_Name  Year  Population  Deaths_All_Types  Deaths_Suicides  \
# 0      Armenia  2006   3219235.0             54404               78
# 1      Armenia  2007   3107395.5             53660                0
# 2      Armenia  2008   3234031.0             54824               63
# 3      Armenia  2009   3066044.0             55120               53
# 4      Armenia  2012   3024127.0             55200               79
#
#    HExp_Pctage_Y  MHExp_Pctage_2011  Dep_Num_2015  Suicide_p100
# 0           5.85               3.38          4.99          5.36
# 1           5.50               3.38          4.99          5.02
# 2           6.64               3.38          4.99          4.23
# 3           8.44               3.38          4.99          4.06
# 4           9.13               3.38          4.99          6.39

# %%
WHO_deaths_df.tail()
# Out:
#     Country_Name  Year  Population  Deaths_All_Types  Deaths_Suicides  \
# 526   Uzbekistan  2015  31298929.0            304070             2392
# 527   Uzbekistan  2016  31847898.0            309582             2467
# 528   Uzbekistan  2017  32388561.0            321446             2417
# 529   Uzbekistan  2018  32956099.0            309826             2278
# 530   Uzbekistan  2019  33580390.0            309138             2318
#
#      HExp_Pctage_Y  MHExp_Pctage_2011  Dep_Num_2015  Suicide_p100
# 526           4.99               2.32          4.23          9.20
# 527           4.97               2.32          4.23          9.21
# 528           5.08               2.32          4.23          8.92
# 529           5.30               2.32          4.23          8.73
# 530           5.62               2.32          4.23          8.28

# %%
WHO_deaths_df.dtypes
# Out:
# Country_Name          object
# Year                   int64
# Population           float64
# Deaths_All_Types       int64
# Deaths_Suicides        int64
# HExp_Pctage_Y        float64
# MHExp_Pctage_2011    float64
# Dep_Num_2015         float64
# Suicide_p100         float64
# dtype: object

# %%
WHO_deaths_df.notnull()
# Out:
#      Country_Name  Year  Population  Deaths_All_Types  Deaths_Suicides  \
# 0            True  True        True              True             True
# 1            True  True        True              True             True
# 2            True  True        True              True             True
# 3            True  True        True              True             True
# 4            True  True        True              True             True
# ..            ...   ...         ...               ...              ...
# 526          True  True        True              True             True
# 527          True  True        True              True             True
# 528          True  True        True              True             True
# 529          True  True        True              True             True
# 530          True  True        True              True             True
#
#      HExp_Pctage_Y  MHExp_Pctage_2011  Dep_Num_2015  Suicide_p100
# ...

# %%
WHO_deaths_df.notnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      Country_Name  Year  Population  Deaths_All_Types  Deaths_Suicides  \
# 0            True  True        True              True             True
# 1            True  True        True              True             True
# 2            True  True        True              True             True
# 3            True  True        True              True             True
# 4            True  True        True              True             True
# ..            ...   ...         ...               ...              ...
# 526          True  True        True              True             True
# 527          True  True        True              True             True
# 528          True  True        True              True             True
# 529          True  True        True              True             True
# 530          True  True        True              True             True
#
# ...

# %%
WHO_deaths_df.isnull()
# Out:
#      Country_Name   Year  Population  Deaths_All_Types  Deaths_Suicides  \
# 0           False  False       False             False            False
# 1           False  False       False             False            False
# 2           False  False       False             False            False
# 3           False  False       False             False            False
# 4           False  False       False             False            False
# ..            ...    ...         ...               ...              ...
# 526         False  False       False             False            False
# 527         False  False       False             False            False
# 528         False  False       False             False            False
# 529         False  False       False             False            False
# 530         False  False       False             False            False
#
#      HExp_Pctage_Y  MHExp_Pctage_2011  Dep_Num_2015  Suicide_p100
# ...

# %%
WHO_deaths_df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      Country_Name   Year  Population  Deaths_All_Types  Deaths_Suicides  \
# 0           False  False       False             False            False
# 1           False  False       False             False            False
# 2           False  False       False             False            False
# 3           False  False       False             False            False
# 4           False  False       False             False            False
# ..            ...    ...         ...               ...              ...
# 526         False  False       False             False            False
# 527         False  False       False             False            False
# 528         False  False       False             False            False
# 529         False  False       False             False            False
# 530         False  False       False             False            False
#
# ...

# %%
WHO_deaths_df.dropna()
# Out:
#     Country_Name  Year  Population  Deaths_All_Types  Deaths_Suicides  \
# 0        Armenia  2006   3219235.0             54404               78
# 1        Armenia  2007   3107395.5             53660                0
# 2        Armenia  2008   3234031.0             54824               63
# 3        Armenia  2009   3066044.0             55120               53
# 4        Armenia  2012   3024127.0             55200               79
# ..           ...   ...         ...               ...              ...
# 526   Uzbekistan  2015  31298929.0            304070             2392
# 527   Uzbekistan  2016  31847898.0            309582             2467
# 528   Uzbekistan  2017  32388561.0            321446             2417
# 529   Uzbekistan  2018  32956099.0            309826             2278
# 530   Uzbekistan  2019  33580390.0            309138             2318
#
#      HExp_Pctage_Y  MHExp_Pctage_2011  Dep_Num_2015  Suicide_p100
# ...

# %%
WHO_deaths_df.columns.tolist()
# Out:
# ['Country_Name',
#  'Year',
#  'Population',
#  'Deaths_All_Types',
#  'Deaths_Suicides',
#  'HExp_Pctage_Y',
#  'MHExp_Pctage_2011',
#  'Dep_Num_2015',
#  'Suicide_p100']

# %%
len(WHO_deaths_df)
# Out:
# 531

# %%
df = pd.DataFrame(WHO_deaths_df)

# %%
df.isna()
# Out:
#      Country_Name   Year  Population  Deaths_All_Types  Deaths_Suicides  \
# 0           False  False       False             False            False
# 1           False  False       False             False            False
# 2           False  False       False             False            False
# 3           False  False       False             False            False
# 4           False  False       False             False            False
# ..            ...    ...         ...               ...              ...
# 526         False  False       False             False            False
# 527         False  False       False             False            False
# 528         False  False       False             False            False
# 529         False  False       False             False            False
# 530         False  False       False             False            False
#
#      HExp_Pctage_Y  MHExp_Pctage_2011  Dep_Num_2015  Suicide_p100
# ...

# %%
df.fillna(0)
# Out:
#     Country_Name  Year  Population  Deaths_All_Types  Deaths_Suicides  \
# 0        Armenia  2006   3219235.0             54404               78
# 1        Armenia  2007   3107395.5             53660                0
# 2        Armenia  2008   3234031.0             54824               63
# 3        Armenia  2009   3066044.0             55120               53
# 4        Armenia  2012   3024127.0             55200               79
# ..           ...   ...         ...               ...              ...
# 526   Uzbekistan  2015  31298929.0            304070             2392
# 527   Uzbekistan  2016  31847898.0            309582             2467
# 528   Uzbekistan  2017  32388561.0            321446             2417
# 529   Uzbekistan  2018  32956099.0            309826             2278
# 530   Uzbekistan  2019  33580390.0            309138             2318
#
#      HExp_Pctage_Y  MHExp_Pctage_2011  Dep_Num_2015  Suicide_p100
# ...
